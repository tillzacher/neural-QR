# %%
from modules.input_gen import generate_qr_code
from modules.input_gen import generate_wifi_qr_string

message = "https://github.com/tillzacher/driving_data_analysis.git"

wifi_ssid = "Vodafone-FD4C"
wifi_password = "pxfy2x2gbq23p3hh"

message = generate_wifi_qr_string(wifi_ssid, wifi_password)
print(message)

filename = "HelloWorld"
border = 6
box_size = 20
mask_logo = 150
inverted = True
add_logo = False

raw_qr_code = generate_qr_code(message, filename=filename, border=border, box_size=box_size, mask_logo=mask_logo, inverted=inverted, add_logo=add_logo)


from modules.input_gen import add_noise_to_qr_code

border_noise_level = 1
noise_level = 0
center_noise_level = 1
mask_logo = mask_logo

noisy_qr = add_noise_to_qr_code(raw_qr_code, filename=filename, border_noise_level=border_noise_level, noise_level=noise_level, center_noise_level=center_noise_level, inverted=inverted, mask_logo=mask_logo)
# Out:
# WIFI:S:Vodafone-FD4C;T:WPA;P:pxfy2x2gbq23p3hh;;
