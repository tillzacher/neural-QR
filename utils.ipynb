# %%
# convert .safetensors model to diffusers format
from modules.converter import convert_safetensors_to_diffusers

path = "models/revAnimated_v2Rebirth.safetensors"
out_dir = convert_safetensors_to_diffusers(path)
print(f"Model converted and saved to: {out_dir}")
# Out:
# c:\Users\Schweini\miniconda3\envs\diffusion\lib\site-packages\torch\_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# c:\Users\Schweini\miniconda3\envs\diffusion\lib\site-packages\transformers\models\clip\feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# Model converted and saved to: C:\Users\Schweini\Documents\qr_code\models\revAnimated_v2Rebirth

# %%
# !pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy
#   Downloading numpy-2.3.3-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Downloading numpy-2.3.3-cp313-cp313-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.8 MB 13.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.2/12.8 MB 13.3 MB/s eta 0:00:01
#    ------------------------- -------------- 8.1/12.8 MB 13.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.0/12.8 MB 13.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 12.7 MB/s  0:00:01
# Installing collected packages: numpy
# Successfully installed numpy-2.3.3
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\Schweini\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
